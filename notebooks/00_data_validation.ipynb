# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from src.data.data_loader import (
    load_supervised_data,
    load_unsupervised_data
)

# %%
### loading supervised and unsupervised data
# supervised dataset
df_supervised = load_supervised_data()
# unsupervised dataset
df_unsupervised = load_unsupervised_data()

# %%
### supervised dataset - overview
# samples
display(df_supervised.head())
# shape
print(f'Supervised dataset shape: {df_supervised.shape}')
# Out:
#    UniqueID  Loan To Value  Branch ID  Age Employment Type  DisbursalDate  \
# 0    417428          88.17         18   53   Self employed          43313
# 1    417429          83.78         13   39        Salaried          43313
# 2    417433          74.89         63   28        Salaried          43313
# 3    417435          73.65         67   35   Self employed          43313
# 4    417438          83.29         16   32        Salaried          43313
#
#    State_ID       State  Employee_code_ID  Mobile Avl Flag  ...  \
# 0       NaN   Louisiana              1998                1  ...
# 1       NaN   Tennessee              1998                1  ...
# 2       NaN  New Jersey              1998                1  ...
# 3       NaN      Nevada              1998                1  ...
# 4       NaN    Illinois              1998                1  ...
#
#    Number of Active Accounts  Number of Overdue Accounts  \
# 0                        3.0                           0
# 1                        1.0                           1
# 2                        2.0                           0
# 3                        0.0                           0
# 4                        2.0                           0
#
#    Current Balance Amount  Sanctioned Amount  Disbursed Amount  \
# 0                   63727             100984            100984
# 1                  103435             100000            100000
# 2                  120985             130600            130600
# 3                       0                  0                 0
# 4                   42588              51320             51320
#
#    Instalment Amount  Number of Accounts Opened Last 6 Months  \
# 0               5571                                        1
# 1             160963                                        0
# 2              15820                                        1
# 3                  0                                        0
# 4               7916                                        3
#
#    Average Account Age  Number of Inquiries  Target
# 0                    9                    0       0
# 1                   36                    0       1
# 2                    1                    0       0
# 3                    6                    0       0
# 4                    4                    0       0
#
# [5 rows x 23 columns]
# Supervised dataset shape: (59477, 23)

# %%
### unsupervised dataset - overview
# samples
display(df_unsupervised.head())
# shape
print(f'Unsupervised dataset shape: {df_unsupervised.shape}')
# Out:
#    UniqueID  Loan To Value  Branch ID  Age Employment Type  DisbursalDate  \
# 0    537409          73.23         67   33   Self employed          43369
# 1    624493          88.48         67   25   Self employed          43399
# 2    518279          89.66         67   28   Self employed          43362
# 3    510278          71.89         67   29        Salaried          43359
# 4    490213          89.56         67   27   Self employed          43348
#
#    State_ID   State  Employee_code_ID  Mobile Avl Flag  ...  \
# 0       NaN  Nevada              1998                1  ...
# 1       NaN  Nevada              1998                1  ...
# 2       NaN  Nevada              1998                1  ...
# 3       NaN  Nevada              1998                1  ...
# 4       NaN  Nevada              1998                1  ...
#
#    Number of Active Accounts  Number of Overdue Accounts  \
# 0                        1.0                           1
# 1                        0.0                           0
# 2                        0.0                           0
# 3                        1.0                           0
# 4                        1.0                           0
#
#    Current Balance Amount  Sanctioned Amount  Disbursed Amount  \
# 0                   27600              50200             50200
# 1                       0                  0                 0
# 2                       0                  0                 0
# 3                   72879              74500             74500
# 4                     -41             365384            365384
#
#    Instalment Amount  Number of Accounts Opened Last 6 Months  \
# 0               1991                                        0
# 1                 31                                        0
# 2               1347                                        0
# 3                  0                                        0
# 4                  0                                        0
#
#    Number of Delinquencies Last 6 Months  Average Account Age  \
# 0                                      1                   13
# 1                                      0                    8
# 2                                      0                   21
# 3                                      0                    2
# 4                                      0                   56
#
#    Number of Inquiries
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    1
#
# [5 rows x 23 columns]
# Unsupervised dataset shape: (59477, 23)
